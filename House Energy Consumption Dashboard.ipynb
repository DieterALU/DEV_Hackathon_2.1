# %% [markdown]
# wdxwxw

# %%
import numpy as np
import pandas as pd
import calendar
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_pickle('power_consumption')

# %%
df.head()
# Out:
#              Date      Time  Global_active_power  Global_reactive_power  \
# 20000  30/12/2006  14:44:00                2.014                  0.402
# 20001  30/12/2006  14:45:00                2.170                  0.512
# 20002  30/12/2006  14:46:00                2.194                  0.520
# 20003  30/12/2006  14:47:00                2.172                  0.514
# 20004  30/12/2006  14:48:00                2.188                  0.518
#
#        Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 20000   240.33               8.6             0.0             1.0
# 20001   240.96               9.2             0.0             0.0
# 20002   241.18               9.2             0.0             0.0
# 20003   240.98               9.2             0.0             0.0
# 20004   241.02               9.2             0.0             0.0
#
#        Sub_metering_3            Datetime
# 20000            18.0 2006-12-30 14:44:00
# 20001            18.0 2006-12-30 14:45:00
# 20002            17.0 2006-12-30 14:46:00
# 20003            18.0 2006-12-30 14:47:00
# 20004            18.0 2006-12-30 14:48:00

# %% [markdown]
# ## The Data is not all the same (Global_avtive_power is in kW and sub_meetering_1 / 2 / 3 are in Units)
# Also the data is not aligned with each other -> Time Stamp it

# %%
df.index = df['Datetime']

# %% [markdown]
# Creating a specific weekly view
# Creating a specific monthly view

# %%
df['Day_name'] = [calendar.day_name[x] for x in df.Datetime.dt.dayofweek]

# %%
year = df['2007-01-01':'2007-03-31']

# %%
year.resample('1d').mean().plot(y='Global_active_power', figsize=(12, 6))

# %%
year.resample('1d').mean().plot(y='Global_active_power''Sub_metering_2', figsize=(12, 6))
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-54-891ecc685f5e> in <module>()
# ----> 1 year.resample('1d').mean().plot(y='Global_active_power'&'Sub_metering_2', figsize=(12, 6))
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
